# %% [markdown]
# Dataset Information
# Additional Information
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012.
# The dataset includes 11 attribues and 1 output attribue (class)
# The 244 instances have been classified into â€˜fireâ€™ (138 classes) and â€˜not fireâ€™ (106 classes) classes.
#
#
# Additional Variable Information
#
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
# Weather data observations
# 2. Temp : temperature noon (temperature max)  in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
# FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system:  7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely  fire and not fire
#
# Steps:
# 1) Data cleaning
# 2) EDA
# 3)Data Visualisation

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('dataset.csv')

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %% [markdown]
# Insights: All the features are object type

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# Split the regions into two part
# 0 -- Bajai
# 1 -- Sidi Bel-abbes

# %%
dataset.loc[:122,"Region"] =0
dataset.loc[122:,"Region"] = 1
df = dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       247 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.1+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %% [markdown]
# Make the Region as int type

# %%
df[["Region"]] = df[["Region"]].astype(int)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %% [markdown]
# Check out the missing values

# %%
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# Region         0
# dtype: int64

# %% [markdown]
# Drop the NAN values

# %%
df = df.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df = df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   1     6  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df = df.drop(['day','month','year'],axis=1).reset_index(drop=True)

# %%
df.head()
# Out:
#   Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4  not fire
# 2          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0  not fire
# 4          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df[['Temperature',	'RH',	'Ws']] = df[['Temperature',	'RH',	'Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    int64
#  1   RH           243 non-null    int64
#  2   Ws           243 non-null    int64
#  3   Rain         243 non-null    object
#  4   FFMC         243 non-null    object
#  5   DMC          243 non-null    object
#  6   DC           243 non-null    object
#  7   ISI          243 non-null    object
#  8   BUI          243 non-null    object
#  9   FWI          243 non-null    object
#  10  Classes      243 non-null    object
#  11  Region       243 non-null    int64
# dtypes: int64(4), object(8)
# memory usage: 22.9+ KB

# %%
df[['FFMC',	'DMC',	'DC',	'ISI',	'BUI',	'FWI']] = df[['FFMC',	'DMC',	'DC',	'ISI',	'BUI',	'FWI']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    int64
#  1   RH           243 non-null    int64
#  2   Ws           243 non-null    int64
#  3   Rain         243 non-null    object
#  4   FFMC         243 non-null    float64
#  5   DMC          243 non-null    float64
#  6   DC           243 non-null    float64
#  7   ISI          243 non-null    float64
#  8   BUI          243 non-null    float64
#  9   FWI          243 non-null    float64
#  10  Classes      243 non-null    object
#  11  Region       243 non-null    int64
# dtypes: float64(6), int64(4), object(2)
# memory usage: 22.9+ KB

# %%
df['Region'].value_counts()
# Out:
# Region
# 0    122
# 1    121
# Name: count, dtype: int64

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Temperature          RH          Ws        FFMC         DMC  \
# count   243.000000  243.000000  243.000000  243.000000  243.000000
# mean     32.152263   62.041152   15.493827   77.842387   14.680658
# std       3.628039   14.828160    2.811385   14.349641   12.393040
# min      22.000000   21.000000    6.000000   28.600000    0.700000
# 25%      30.000000   52.500000   14.000000   71.850000    5.800000
# 50%      32.000000   63.000000   15.000000   83.300000   11.300000
# 75%      35.000000   73.500000   17.000000   88.300000   20.800000
# max      42.000000   90.000000   29.000000   96.000000   65.900000
#
#                DC         ISI         BUI         FWI      Region
# count  243.000000  243.000000  243.000000  243.000000  243.000000
# mean    49.430864    4.742387   16.690535    7.035391    0.497942
# std     47.665606    4.154234   14.228421    7.440568    0.501028
# min      6.900000    0.000000    1.100000    0.000000    0.000000
# ...

# %%
##EDA
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16     0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df.tail()
# Out:
#      Temperature  RH  Ws Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14    0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15  4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29  0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18  0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15  0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

# %%
plt.style.use('seaborn')
df['Classes'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Classes'>

# %% [markdown]
# total number of fires - 137
# total number of not fire - 106

# %%
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
df['Temperature'].min()
# Out:
# 22

# %%
df['Temperature'].max()
# Out:
# 42

# %% [markdown]
# Min temp was 22 celcius and max was 42

# %%
for i in df.columns:
    sns.displot(df[i])
    plt.show()

# %%
percentage = df['Classes'].value_counts(normalize=True)

# %%
classlabels = ["fire","not fire"]
plt.figure(figsize=(8,8))
plt.pie(percentage,labels=classlabels,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x794a416cd780>,
# ...
#  [Text(-0.21895639684834634, 1.0779879852202388, 'fire'),
#   Text(0.21895649777686463, -1.0779879647200568, 'not fire')],
#  [Text(-0.1194307619172798, 0.5879934464837665, '56.38%'),
#   Text(0.11943081696919887, -0.587993435301849, '43.62%')])

# %% [markdown]
# Total region having fire was  56.38 %
# and not fire was 43.62%

# %%
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# output feature classes is positively co-related with temp,ffmc,dmc,dc,isi,bui
# while it is negatively co-related with rh,ws,rain

# %%
for i in df.columns:
  plt.figure(figsize=(10,5))
  sns.boxplot(df[i],color='green')

# %% [markdown]
# Insights : tempreture,classes and region does not have outliers while all other features have some outliers

# %%
##monthly fire analysis:
dftemp = df.loc[df['Region'] == 1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='Region',hue='Classes',data=dftemp)
plt.ylabel('number of fires',weight='bold')
plt.xlabel('month',weight='bold')
plt.title('monthly fire analysis',weight='bold')
#
#
# Out:
# Text(0.5, 1.0, 'monthly fire analysis')

# %% [markdown]
# Insight of bajai region
# no of fires was 78 and not fire was 42

# %%
dftemp = df.loc[df['Region'] == 0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='Region',hue='Classes',data=dftemp)
plt.ylabel('number of fires',weight='bold')
plt.xlabel('month',weight='bold')
plt.title('monthly fire analysis',weight='bold')
# Out:
# Text(0.5, 1.0, 'monthly fire analysis')

# %% [markdown]
# Insights for Sidi Bel-abbes region
# no of fires was approx 52 while no of not fires was 63
# hence there was less fire in a particular month as compared to bajai region
